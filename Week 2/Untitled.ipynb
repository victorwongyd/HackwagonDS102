# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('pokemon.csv')

# %%
df
# Out:
#      Pokemon_ID                       Name      Type   HP  Attack  Defense  \
# 0             1                  Bulbasaur     Grass   45      49       49
# 1             2                    Ivysaur     Grass   60      62       63
# 2             3                   Venusaur     Grass   80      82       83
# 3             3      VenusaurMega Venusaur     Grass   80     100      123
# 4             4                 Charmander      Fire   39      52       43
# 5             5                 Charmeleon      Fire   58      64       58
# 6             6                  Charizard      Fire   78      84       78
# 7             6  CharizardMega Charizard X      Fire   78     130      111
# 8             6  CharizardMega Charizard Y      Fire   78     104       78
# 9             7                   Squirtle     Water   44      48       65
# 10            8                  Wartortle     Water   59      63       80
# ...

# %%
df.head()
# Out:
#    Pokemon_ID                   Name   Type  HP  Attack  Defense  Speed  \
# 0           1              Bulbasaur  Grass  45      49       49     45
# 1           2                Ivysaur  Grass  60      62       63     60
# 2           3               Venusaur  Grass  80      82       83     80
# 3           3  VenusaurMega Venusaur  Grass  80     100      123     80
# 4           4             Charmander   Fire  39      52       43     65
#
#    Legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
df.tail()
# Out:
#      Pokemon_ID                 Name     Type  HP  Attack  Defense  Speed  \
# 795         719              Diancie     Rock  50     100      150     50
# 796         719  DiancieMega Diancie     Rock  50     160      110    110
# 797         720  HoopaHoopa Confined  Psychic  80     110       60     70
# 798         720   HoopaHoopa Unbound  Psychic  80     160       60     80
# 799         721            Volcanion     Fire  80     110      120     70
#
#      Legendary
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True

# %%
grass_df = df.copy()
grass_df = grass_df[grass_df['Type'] == 'Grass']
grass_df_HP50 = grass_df[grass_df['HP'] >= 50]
grass_df_HP50.describe()
# Out:
#        Pokemon_ID          HP      Attack     Defense       Speed
# count   57.000000   57.000000   57.000000   57.000000   57.000000
# mean   351.403509   73.157895   80.789474   75.368421   66.245614
# std    201.720445   16.574280   21.538783   23.881128   28.866244
# min      2.000000   50.000000   40.000000   35.000000   15.000000
# 25%    188.000000   60.000000   62.000000   60.000000   46.000000
# 50%    387.000000   70.000000   80.000000   72.000000   60.000000
# 75%    497.000000   80.000000  100.000000   85.000000   83.000000
# max    673.000000  123.000000  132.000000  131.000000  145.000000

# %%
grass_fire_water_df = df.copy()
interest = ['Grass', 'Water', 'Fire']
grass_fire_water_df = grass_fire_water_df[grass_fire_water_df['Type'].isin(interest)]
grass_fire_water_df.groupby('Type').size().reset_index(name= "No. of Pokemons")
# Out:
#     Type  No. of Pokemons
# 0   Fire               52
# 1  Grass               70
# 2  Water              112
